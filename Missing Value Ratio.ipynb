# %% [markdown]
# ## Missing Value Ratio

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("NaN_Housing_Prices.csv")

# %%
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                  NaN              7
# 1              7242.0           2.0                  NaN              7
# 2             10000.0           1.0                  NaN              6
# 3              5000.0           1.0                  NaN              7
# 4              8080.0           1.0                  NaN              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %%
data.shape
# Out:
# (21609, 31)

# %%
data.isnull().sum()
# Out:
# Sale_Price                                       0
# No of Bedrooms                                   0
# No of Bathrooms                                  0
# Flat Area (in Sqft)                              0
# Lot Area (in Sqft)                               0
# No of Floors                                     0
# No of Times Visited                          19485
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        0
# Basement Area (in Sqft)                      13123
# Age of House (in Years)                          0
# Latitude                                         0
# Longitude                                        0
# Living Area after Renovation (in Sqft)           0
# Lot Area after Renovation (in Sqft)              0
# Years Since Renovation                       20695
# Condition_of_the_House_Excellent                 0
# Condition_of_the_House_Fair                      0
# ...

# %%
### Missing Value Ratio formula ###

# Missing value ratio = number of missing values/Total no.of observations

# %%
for i in data.columns:
    tmp = data[i].isnull().sum()/len(data)   ## formula
    if tmp > 0.70:
        print("removing column" + i + "with missing value ratio",tmp)
        data = data.drop(columns = [i])
# Out:
# removing columnNo of Times Visitedwith missing value ratio 0.9017076218242399
# removing columnYears Since Renovationwith missing value ratio 0.9577028090147623
